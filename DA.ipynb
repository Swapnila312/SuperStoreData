# %% [markdown]
# # Import the essential library

# %%
# Load the necessary library
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Read the dataset

# %%
# Load the dataset
df=pd.read_csv("SampleSuperstore.csv")

# %% [markdown]
# # Dimensions of the dataset

# %%
# No. of rows and columns in the given data
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# # Peek into the content of the dataset

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # Drop the unnecessary column

# %%
# Drop unnecessary columns like postal code
df.drop(columns="Postal Code",inplace=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Ship Mode

# %%
print("Total no. of Shipping modes:",df["Ship Mode"].nunique())
print(df["Ship Mode"].unique())
# Out:
# Total no. of Shipping modes: 4
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %% [markdown]
# # Segment

# %%
print("Total no. of segments:",df["Segment"].nunique())
print(df["Segment"].unique())
# Out:
# Total no. of segments: 3
# ['Consumer' 'Corporate' 'Home Office']

# %% [markdown]
# # Country

# %%
print("Total no. of Countries:",df["Country"].nunique())
print(df["Country"].unique())
# Out:
# Total no. of Countries: 1
# ['United States']

# %% [markdown]
# # Category

# %%
print("Total no. of product categories:",df["Category"].nunique())
print(df["Category"].unique())
print("No. of products in each category:\n",df["Category"].value_counts())
# Out:
# Total no. of product categories: 3
# ['Furniture' 'Office Supplies' 'Technology']
# No. of products in each category:
#  Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# # Sub- category

# %%
print("Total no. of sub-categories of product:",df["Sub-Category"].nunique())
print(df["Sub-Category"].unique())
print("No. of products in each sub-category:\n",df["Sub-Category"].value_counts())
# Out:
# Total no. of sub-categories of product: 17
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
# No. of products in each sub-category:
#  Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# # Region

# %%
print("Types of region:",df["Region"].nunique())
print(df["Region"].unique())
# Out:
# Types of region: 4
# ['South' 'West' 'Central' 'East']

# %% [markdown]
# # No. of unique values in each column

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Summary of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %% [markdown]
# # Statistical Description of data

# %%
# Statistical description of data
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # Total no. of null values

# %%
# Sum of all missing values
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Data type of each column

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# # No. of duplicate values in data

# %%
df.duplicated().sum()
# Out:
# 50

# %% [markdown]
# # Drop duplicate values in the dataset

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Correlation among the columns

# %%
df.corr()
# Out:
# C:\Users\my pc\AppData\Local\Temp\ipykernel_23460\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200469 -0.028625  0.479078
# Quantity  0.200469  1.000000  0.008307  0.066089
# Discount -0.028625  0.008307  1.000000 -0.219939
# Profit    0.479078  0.066089 -0.219939  1.000000

# %% [markdown]
# # Convariance between set of variables

# %%
df.cov()
# Out:
# C:\Users\my pc\AppData\Local\Temp\ipykernel_23460\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                   Sales    Quantity   Discount        Profit
# Sales     390181.082925  279.088165  -3.693757  70277.064208
# Quantity     279.088165    4.967335   0.003825     34.591355
# Discount      -3.693757    0.003825   0.042677    -10.670204
# Profit     70277.064208   34.591355 -10.670204  55150.469191

# %% [markdown]
# # Slicing of data

# %%
df.iloc[0]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Region                  South
# Category            Furniture
# Sub-Category        Bookcases
# Sales                  261.96
# Quantity                    2
# Discount                  0.0
# Profit                41.9136
# Name: 0, dtype: object

# %% [markdown]
# # Statistical Analysis of data

# %%
#Total sale of a region
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Central    500724.2708
# East       677843.9080
# South      391721.9050
# West       724309.2935
# Name: Sales, dtype: float64

# %%
# Average sales of a region
df.groupby("Region")["Sales"].mean()
# Out:
# Region
# Central    216.295581
# East       239.351662
# South      241.803645
# West       227.985299
# Name: Sales, dtype: float64

# %%
#Total Sale of a Category of product
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          740568.6663
# Office Supplies    718256.0700
# Technology         835774.6410
# Name: Sales, dtype: float64

# %%
# Average sale of a category of product
df.groupby("Category")["Sales"].mean()
# Out:
# Category
# Furniture          350.316304
# Office Supplies    119.989320
# Technology         453.240044
# Name: Sales, dtype: float64

# %%
# Total sale of a sub-category of product
df.groupby("Sub-Category")["Sales"].sum()
# Out:
# Sub-Category
# Accessories    167303.3020
# Appliances     107532.1610
# Art             27065.7320
# Binders        203328.8590
# Bookcases      114166.9293
# Chairs         327777.7610
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91658.4440
# Labels          12385.7640
# Machines       189238.6310
# Paper           77960.8940
# Phones         329704.6780
# Storage        223808.4400
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
# Average sale of a sub-category of product
df.groupby("Sub-Category")["Sales"].mean()
# Out:
# Sub-Category
# Accessories     216.433767
# Appliances      230.755710
# Art              34.130810
# Binders         133.945230
# Bookcases       505.163404
# Chairs          532.971969
# Copiers        2198.941618
# Envelopes        64.867724
# Fasteners        13.936774
# Furnishings      96.078034
# Labels           34.500735
# Machines       1645.553313
# Paper            58.006618
# Phones          371.289052
# Storage         264.862059
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %% [markdown]
# # visualization

# %%
# Pie plot of subcategory
plt.figure(figsize=(10,10))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
# Sales analysis based on region
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
# Sales analysis by region using pie chart
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
# Profit analysis based on region
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
# Profit analysis by region using pie chart
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
# Sales analysis by segment
df.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
# Profit analysis by segment
df.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
# Sales analysis by Category
df.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
# Profit analysis by Category
df.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
# Sales analysis by Category using pie chart
df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
# Profit analysis by Category using pie chart
df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
# Sales analysis by State
df.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
# Profit analysis by State
df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
# Bar plot of sales vs profit
df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title('Total profit and sales per sub category')
plt.show()
# Out:
# C:\Users\my pc\AppData\Local\Temp\ipykernel_23460\453387730.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()

# %%
# Histogram of data
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
# Statistical summary by state
df.groupby('State').Profit.agg(['sum','mean','min','max','count','median'])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76215.9705   38.492914  -325.5720  1906.4850   1980
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12593.2976  -25.700607 -2929.4845   874.9875    490
# ...
